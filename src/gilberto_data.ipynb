# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ice_data    = np.loadtxt("ice.csv", comments = '!', delimiter = ',') 
no_ice_data = np.loadtxt("no_ice.csv", comments = '!', delimiter = ',')

# %%
no_ice_data
# Out:
# array([[ 1.00000000e+08, -7.55489935e-01],
#        [ 1.03500000e+08, -8.64522978e-01],
#        [ 1.07000000e+08, -8.38967645e-01],
#        [ 1.10500000e+08, -8.41326641e-01],
#        [ 1.14000000e+08, -9.02643591e-01],
#        [ 1.17500000e+08, -9.57635762e-01],
#        [ 1.21000000e+08, -9.76202954e-01],
#        [ 1.24500000e+08, -9.56982962e-01],
#        [ 1.28000000e+08, -8.54160797e-01],
#        [ 1.31500000e+08, -7.24350713e-01],
#        [ 1.35000000e+08, -5.73029760e-01],
#        [ 1.38500000e+08, -4.52230861e-01],
#        [ 1.42000000e+08, -3.87387016e-01],
#        [ 1.45500000e+08, -3.74796276e-01],
#        [ 1.49000000e+08, -4.43800869e-01],
#        [ 1.52500000e+08, -5.68632232e-01],
#        [ 1.56000000e+08, -7.47256405e-01],
#        [ 1.59500000e+08, -9.86393177e-01],
#        [ 1.63000000e+08, -1.22865401e+00],
#        [ 1.66500000e+08, -1.45022095e+00],
#        [ 1.70000000e+08, -1.63114075e+00],
#        [ 1.73500000e+08, -1.73558689e+00],
# ...

# %%
ice_data[:, 0]
# Out:
# array([1.000e+08, 1.035e+08, 1.070e+08, 1.105e+08, 1.140e+08, 1.175e+08,
#        1.210e+08, 1.245e+08, 1.280e+08, 1.315e+08, 1.350e+08, 1.385e+08,
#        1.420e+08, 1.455e+08, 1.490e+08, 1.525e+08, 1.560e+08, 1.595e+08,
#        1.630e+08, 1.665e+08, 1.700e+08, 1.735e+08, 1.770e+08, 1.805e+08,
#        1.840e+08, 1.875e+08, 1.910e+08, 1.945e+08, 1.980e+08, 2.015e+08,
#        2.050e+08, 2.085e+08, 2.120e+08, 2.155e+08, 2.190e+08, 2.225e+08,
#        2.260e+08, 2.295e+08, 2.330e+08, 2.365e+08, 2.400e+08, 2.435e+08,
#        2.470e+08, 2.505e+08, 2.540e+08, 2.575e+08, 2.610e+08, 2.645e+08,
#        2.680e+08, 2.715e+08, 2.750e+08, 2.785e+08, 2.820e+08, 2.855e+08,
#        2.890e+08, 2.925e+08, 2.960e+08, 2.995e+08, 3.030e+08, 3.065e+08,
#        3.100e+08, 3.135e+08, 3.170e+08, 3.205e+08, 3.240e+08, 3.275e+08,
#        3.310e+08, 3.345e+08, 3.380e+08, 3.415e+08, 3.450e+08, 3.485e+08,
#        3.520e+08, 3.555e+08, 3.590e+08, 3.625e+08, 3.660e+08, 3.695e+08,
# ...

# %%
plt.plot(ice_data[:, 0], ice_data[:, 1])
plt.plot(no_ice_data[:, 0], no_ice_data[:, 1])

plt.grid()
plt.xlim(1.5*1e8, 4.5*1e8)
# Out:
# (150000000.0, 450000000.0)
