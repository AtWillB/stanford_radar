# %%
from temp_profile import TempProfile1D
from temp_profile import TempProfile2D

import numpy as np
import glob

# %%
folderpath = "../data/gaia/temp_profile/europa/EuropaParameterStudy/"
twod_sims = glob.glob(folderpath+"*_2D_data.txt")

# %%
example_prof = TempProfile2D.from_filepath(twod_sims[0])

# %%
example_prof.plot_relative_eutectic_depth()

# %%
# Out:
# Temp range: 110.0 K - 270.7 K,
# Ice Shell Depth: 25.0 Km,
# Resolution: 136.0 m,
# nShells: 12174,
# nCellsPerShell: 186

# %%
# Out:
# 186.0
