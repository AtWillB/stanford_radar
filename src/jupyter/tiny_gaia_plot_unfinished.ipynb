# %%
from temp_profile import TempProfile2D
from eutectic_interface import EuteticInterface

import glob
import numpy as np
import pandas as pd

from scipy.stats import pearsonr
from scipy.signal import find_peaks, peak_prominences

import matplotlib.pyplot as plt
import seaborn as sns

# %%
ex_filepath = "../data/gaia/temp_profile/europa/EuropaParameterStudy/Europa_D40km_eta1e+15_2D_data.txt"
ex_prof = TempProfile2D.from_filepath(ex_filepath)

# %%
ex_prof.plot_temp_twod()
# Out:
# [[269.18734041 269.18734041 269.18734041 ... 269.18734041 269.18734041
#   269.18734041]
#  [269.13854168 269.13854168 269.13717494 ... 269.11391969 269.11578856
#   269.11578856]
#  [269.03805379 269.03805379 269.03366043 ... 268.96429161 268.97032676
#   268.97032676]
#  ...
#  [111.74182625 111.74182625 111.74179434 ... 111.67320616 111.67321859
#   111.67321859]
#  [110.58056782 110.58056782 110.58055719 ... 110.55769828 110.55770242
#   110.55770242]
#  [110.         110.         110.         ... 110.         110.
#   110.        ]]
